# %% [markdown]
# # Pandas
# [Official website](https://pandas.pydata.org/)

# %%
from platform import python_version

print(f"Python notebook version: {python_version()}")
# Out:
# Python notebook version: 3.8.2

# %%
import numpy as np
import pandas as pd

# %%
# Check versions
print(f'Numpy library version: {np.__version__}')
print(f'Pandas library version: {pd.__version__}')
# Out:
# Numpy library version: 1.18.4
# Pandas library version: 1.0.3

# %% [markdown]
# ## Data structure

# %% [markdown]
# The two primary data structure:
# * Series, 1-dimensinal scalars container
# * DataFrames, 2-dimensial container for Series

# %%
# Create a Series
numbers = pd.Series([1, 2, 3, 4, 5])
numbers
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Create a DataFrame
df = pd.DataFrame({
    "Name": ["Braund, Mr. Owen Harris", "Allen, Mr. William Henry","Bonnell, Miss. Elizabeth"], 
    "Age": [22, 35, 58], 
    "Sex": ["male", "male", "female"]
})
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
# Another way to create it ...
# Define data sequence
dates = pd.date_range("today", periods=6)
# Create random number dimensinal matrix by np
num_arr = np.random.randn(6,4)
# Column could be anything, not only numbers
columns = ["a", "b", "c", "d"]
# Create data frame
df_dates = pd.DataFrame(num_arr, index=dates, columns=columns)
df_dates
# Out:
#                                    a         b         c         d
# 2020-05-05 17:12:28.423791  1.108375 -0.890295 -0.836335 -1.549884
# 2020-05-06 17:12:28.423791  0.362425  1.672179  0.431479  0.989065
# 2020-05-07 17:12:28.423791 -0.297348 -0.528574 -0.265172 -1.131690
# 2020-05-08 17:12:28.423791 -0.460902 -0.583882  1.043059  1.147121
# 2020-05-09 17:12:28.423791  0.634314  1.137777  0.205541 -1.365491
# 2020-05-10 17:12:28.423791 -1.415470 -0.116189 -1.102400  0.372251

# %% [markdown]
# Something important: the first column are indexes form each row to locate them.

# %%
# Use columns
df_dates["a"].sum()
# Out:
# -0.06860637261330993

# %% [markdown]
# ## Load data

# %% [markdown]
# Dataframe: index and series

# %%
# As Pandas DataFrame from a file: csv, xslx, txt
df = pd.read_csv("housing.csv")
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Show index
df.index
# Out:
# RangeIndex(start=0, stop=20640, step=1)

# %% [markdown]
# The numbers are the indexes for this dataset.

# %%
# and colums
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# Show columns types
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
# DataFrame dimension
df.shape
# Out:
# (20640, 10)

# %%
# Show some statistics
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# Show the head of the table
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Or the tail
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
# Check nulls
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %% [markdown]
# ## Select

# %%
# Select rows
df[0:20]
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# ...

# %%
# columns and combine them
df[["total_rooms", "population"]][0:12]
# Out:
#     total_rooms  population
# 0         880.0       322.0
# 1        7099.0      2401.0
# 2        1467.0       496.0
# 3        1274.0       558.0
# 4        1627.0       565.0
# 5         919.0       413.0
# 6        2535.0      1094.0
# 7        3104.0      1157.0
# 8        2555.0      1206.0
# 9        3549.0      1551.0
# 10       2202.0       910.0
# 11       3503.0      1504.0

# %% [markdown]
# ## Iterate

# %%
for index, row in df_dates.iterrows():
    print(index, row["a"])
# Out:
# 2020-05-05 17:12:28.423791 1.1083747379789968
# 2020-05-06 17:12:28.423791 0.36242455266072693
# 2020-05-07 17:12:28.423791 -0.2973479254913505
# 2020-05-08 17:12:28.423791 -0.46090191050293655
# 2020-05-09 17:12:28.423791 0.6343140346893742
# 2020-05-10 17:12:28.423791 -1.4154698619481207

# %% [markdown]
# ## Filter

# %%
# Slicing dataframe
df.iloc[1:20]
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# 12    -122.26     37.85                52.0       2491.0           474.0
# ...

# %%
# and filter by housing_median_age and take the first 20 rows
df[df["housing_median_age"] == 21.0][:20]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1       -122.22     37.86                21.0       7099.0          1106.0
# 50      -122.27     37.82                21.0        896.0           453.0
# 568     -122.24     37.73                21.0       7031.0          1249.0
# 662     -122.13     37.70                21.0       4124.0          1054.0
# 703     -122.04     37.63                21.0       1307.0           236.0
# 758     -122.07     37.66                21.0       5031.0          1168.0
# 859     -121.97     37.57                21.0       4342.0           783.0
# 889     -121.95     37.55                21.0      10687.0          1540.0
# 944     -122.02     37.53                21.0       4280.0           673.0
# 1088    -121.81     39.70                21.0       5051.0          1054.0
# 1185    -121.52     39.48                21.0       2628.0           494.0
# ...

# %%
# or filter the first 20, then by housing_median_age
df[:20].loc[df["housing_median_age"] == 21.0]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
# Locate group of row of specific one
df[(df["ocean_proximity"] == "NEAR BAY") | (df["ocean_proximity"] == "INLAND")]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# Locate group of row of specific one
df[df["ocean_proximity"].isin(["INLAND", "NEAR BAY"])]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# String like ...
df[df["ocean_proximity"].str.contains("LAND")]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 954      -121.92     37.64                46.0       1280.0           209.0
# 957      -121.90     37.66                18.0       7397.0          1137.0
# 965      -121.88     37.68                23.0       2234.0           270.0
# 967      -121.88     37.67                16.0       4070.0           624.0
# 968      -121.88     37.67                25.0       2244.0           301.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# String not like ... (not ! => ~)
df[~df["ocean_proximity"].str.contains("LAND")]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20502    -118.68     34.33                45.0        121.0            25.0
# 20503    -118.75     34.33                27.0        534.0            85.0
# 20504    -118.73     34.29                11.0       5451.0           736.0
# 20505    -118.72     34.29                22.0       3266.0           529.0
# 20506    -118.73     34.29                 8.0       4983.0           754.0
#
# ...

# %%
import re
# Use regular expressions, ignoring capital cases (flags) if you want
df[df["ocean_proximity"].str.contains("bay|ocean", regex=True, flags=re.I)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20502    -118.68     34.33                45.0        121.0            25.0
# 20503    -118.75     34.33                27.0        534.0            85.0
# 20504    -118.73     34.29                11.0       5451.0           736.0
# 20505    -118.72     34.29                22.0       3266.0           529.0
# 20506    -118.73     34.29                 8.0       4983.0           754.0
#
# ...

# %% [markdown]
# ## Sort

# %%
# One arguments
df.sort_values(["housing_median_age"], ascending=False)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18881    -122.25     38.10                52.0        248.0            86.0
# 1671     -122.21     38.06                52.0       2735.0           559.0
# 19116    -122.65     38.23                52.0       1735.0           347.0
# 19516    -121.01     37.64                52.0        201.0            35.0
# 16200    -121.27     37.95                52.0       1318.0           308.0
# ...          ...       ...                 ...          ...             ...
# 12077    -117.64     33.87                 2.0      17470.0          2727.0
# 18972    -122.00     38.23                 1.0       2062.0           343.0
# 12286    -116.95     33.86                 1.0          6.0             2.0
# 3130     -117.95     35.08                 1.0         83.0            15.0
# 19536    -120.93     37.65                 1.0       2254.0           328.0
#
# ...

# %%
# Or more
df.sort_values(["housing_median_age", "ocean_proximity"], ascending=[True, False])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3130     -117.95     35.08                 1.0         83.0            15.0
# 12286    -116.95     33.86                 1.0          6.0             2.0
# 18972    -122.00     38.23                 1.0       2062.0           343.0
# 19536    -120.93     37.65                 1.0       2254.0           328.0
# 15444    -117.26     33.19                 2.0       2629.0           509.0
# ...          ...       ...                 ...          ...             ...
# 19266    -122.72     38.44                52.0        188.0            62.0
# 19341    -122.87     38.62                52.0       1514.0           348.0
# 19342    -122.86     38.61                52.0       1753.0           380.0
# 20141    -119.06     34.36                52.0       1409.0           359.0
# 20142    -119.06     34.36                52.0       1239.0           320.0
#
# ...

# %% [markdown]
# ## Aggregation

# %%
# Distinct value in a column
df["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# Group by and how
df.groupby(["ocean_proximity"]).mean().sort_values("median_income")
# Out:
#                   longitude   latitude  housing_median_age  total_rooms  \
# ocean_proximity
# ISLAND          -118.354000  33.358000           42.400000  1574.600000
# INLAND          -119.732990  36.731829           24.271867  2717.742787
# NEAR OCEAN      -119.332555  34.738439           29.347254  2583.700903
# NEAR BAY        -122.260694  37.801057           37.730131  2493.589520
# <1H OCEAN       -118.847766  34.560577           29.279225  2628.343586
#
#                  total_bedrooms   population  households  median_income  \
# ocean_proximity
# ISLAND               420.400000   668.000000  276.600000       2.744420
# INLAND               533.881619  1391.046252  477.447565       3.208996
# NEAR OCEAN           538.615677  1354.008653  501.244545       4.005785
# NEAR BAY             514.182819  1230.317467  488.616157       4.172885
# <1H OCEAN            546.539185  1520.290499  517.744965       4.230682
#
#                  median_house_value
# ocean_proximity
# ...

# %%
df.groupby(["ocean_proximity"]).std()
# Out:
#                  longitude  latitude  housing_median_age  total_rooms  \
# ocean_proximity
# <1H OCEAN         1.588888  1.467127           11.644453  2160.463696
# INLAND            1.900950  2.116073           12.018020  2385.831111
# ISLAND            0.070569  0.040866           13.164346   707.545264
# NEAR BAY          0.147004  0.185434           13.070385  1830.817022
# NEAR OCEAN        2.327307  2.275386           11.840371  1990.724760
#
#                  total_bedrooms   population  households  median_income  \
# ocean_proximity
# <1H OCEAN            427.911417  1185.848357  392.280718       2.001223
# INLAND               446.117778  1168.670126  392.252095       1.437465
# ISLAND               169.320111   301.691067  113.200265       0.444180
# NEAR BAY             367.887605   885.899035  350.598369       2.017427
# NEAR OCEAN           376.320045  1005.563166  344.445256       2.010558
#
#                  median_house_value
# ocean_proximity
# ...

# %% [markdown]
# ## Transformation

# %%
# Transpose
df3.T
# Out:
#    2020-05-05 15:55:36.272655  2020-05-06 15:55:36.272655  \
# a                    0.929176                    0.650564
# b                   -0.563820                   -0.545791
# c                   -1.959712                    3.599031
# d                    1.758003                    2.588210
#
#    2020-05-07 15:55:36.272655  2020-05-08 15:55:36.272655  \
# a                   -0.513420                    1.284680
# b                    1.195735                    0.106376
# c                    0.626662                    0.184929
# d                   -0.831534                   -0.309290
#
#    2020-05-09 15:55:36.272655  2020-05-10 15:55:36.272655
# a                   -2.154018                   -0.812161
# b                    0.204647                    0.555391
# c                    0.566684                   -0.483624
# d                   -0.424346                   -0.109190

# %%
# Create new colums
df["value_by_income"] = df["median_house_value"] / df["median_income"]
# Show subset
df[["value_by_income", "median_house_value", "median_income"]]
# Out:
#        value_by_income  median_house_value  median_income
# 0         54365.060299            452600.0         8.3252
# 1         43185.486785            358500.0         8.3014
# 2         48515.997465            352100.0         7.2574
# 3         60480.941327            341300.0         5.6431
# 4         88970.932349            342200.0         3.8462
# ...                ...                 ...            ...
# 20635     50054.476703             78100.0         1.5603
# 20636     30154.881101             77100.0         2.5568
# 20637     54294.117647             92300.0         1.7000
# 20638     45362.039417             84700.0         1.8672
# 20639     37427.781964             89400.0         2.3886
#
# [20640 rows x 3 columns]

# %%
# Drop a column
df = df.drop(columns=["value_by_income"])
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# Update our dataset filtering it. Reset indexes (reset_index)
df = df[ (df["housing_median_age"] >= 10) & (df["housing_median_age"] <= 20)].reset_index(drop=True)
# Updated dataset 4988x10
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.29     37.81                20.0        835.0           161.0
# 1       -122.28     37.81                17.0       1237.0           462.0
# 2       -122.28     37.81                19.0       1207.0           243.0
# 3       -122.28     37.81                17.0        924.0           289.0
# 4       -122.27     37.81                10.0        875.0           348.0
# ...         ...       ...                 ...          ...             ...
# 4983    -121.45     39.26                15.0       2319.0           416.0
# 4984    -121.21     39.49                18.0        697.0           150.0
# 4985    -121.22     39.43                17.0       2254.0           485.0
# 4986    -121.32     39.43                18.0       1860.0           409.0
# 4987    -121.24     39.37                16.0       2785.0           616.0
#
#       population  households  median_income  median_house_value  \
# ...

# %%
# Change values
df.loc[df["ocean_proximity"] == "<1H OCEAN", "ocean_proximity"] = "< OCEAN"
# Check filter by
df.loc[df["ocean_proximity"].str.contains("<", regex=True)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 60      -121.96     37.58                15.0       3575.0           597.0
# 61      -121.98     37.58                20.0       4126.0          1031.0
# 66      -121.99     37.56                18.0       5505.0          1005.0
# 67      -121.99     37.56                20.0       6462.0          1294.0
# 68      -121.97     37.56                13.0       8918.0          1823.0
# ...         ...       ...                 ...          ...             ...
# 4940    -118.68     34.27                16.0       4637.0           941.0
# 4941    -118.67     34.27                15.0       3221.0           659.0
# 4942    -118.67     34.27                10.0       3753.0           678.0
# 4943    -118.71     34.30                20.0       1586.0           187.0
# 4944    -118.73     34.29                11.0       5451.0           736.0
#
#       population  households  median_income  median_house_value  \
# ...

# %% [markdown]
# #### Operations with missing values

# %%
# Dataframe with null
df5 = pd.DataFrame(np.array([[1, 2, 3], [np.nan, 5, 6], [7, 8, 9]]),
                   columns=['a', 'b', 'c'])
df5.isnull()
# Out:
#        a      b      c
# 0  False  False  False
# 1   True  False  False
# 2  False  False  False

# %%
# Calculate mean and fill null values
df5.fillna(df5["a"].mean())
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0

# %%
# Could drop this rows
df6 = pd.DataFrame(np.array([[1, 2, 3], [np.nan, 5, 6], [7, 8, 9]]),
                   columns=['a', 'b', 'c'])
df6.dropna(how="any")
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 2  7.0  8.0  9.0

# %% [markdown]
# #### Remove duplicates

# %%
data = {"Name": ["James", "Alice", "Phil", "James"],
        "Age": [24, 28, 40, 24],
        "Sex": ["Male", "Female", "Male", "Male"]}
df_duplicates = pd.DataFrame(data)
df_duplicates
# Out:
#     Name  Age     Sex
# 0  James   24    Male
# 1  Alice   28  Female
# 2   Phil   40    Male
# 3  James   24    Male

# %%
df_without_duplicates = df_duplicates.drop_duplicates()
df_without_duplicates
# Out:
#     Name  Age     Sex
# 0  James   24    Male
# 1  Alice   28  Female
# 2   Phil   40    Male

# %% [markdown]
# ## Join tables

# %%
air_quality_pm25 = pd.read_csv("air-pm25.csv", parse_dates=True)
air_quality_no2 = pd.read_csv("air-no2.csv", parse_dates=True)

# %%
air_quality_no2.shape
# Out:
# (2068, 7)

# %%
air_quality_pm25.shape
# Out:
# (1110, 7)

# %%
air_quality_no2.head()
# Out:
#     city country                   date.utc location parameter  value   unit
# 0  Paris      FR  2019-06-21 00:00:00+00:00  FR04014       no2   20.0  µg/m³
# 1  Paris      FR  2019-06-20 23:00:00+00:00  FR04014       no2   21.8  µg/m³
# 2  Paris      FR  2019-06-20 22:00:00+00:00  FR04014       no2   26.5  µg/m³
# 3  Paris      FR  2019-06-20 21:00:00+00:00  FR04014       no2   24.9  µg/m³
# 4  Paris      FR  2019-06-20 20:00:00+00:00  FR04014       no2   21.4  µg/m³

# %%
air_quality_pm25.head()
# Out:
#         city country                   date.utc location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³

# %%
# Union by row = axis zero
air_quality = pd.concat([air_quality_pm25, air_quality_no2], axis=0)
air_quality.shape
# Out:
# (3178, 7)

# %%
air_stations = pd.DataFrame({
    "location": ["FR04014", "BELHB23", "BELLD01", "BELLD02", "BETR801"],
    "longitude": [51.23619, 51.17030, 51.10998, 51.12038, 51.32766],
    "latitude": [4.38522, 4.34100, 5.00486, 5.02155, 4.36226]
})
air_stations
# Out:
#   location  longitude  latitude
# 0  FR04014   51.23619   4.38522
# 1  BELHB23   51.17030   4.34100
# 2  BELLD01   51.10998   5.00486
# 3  BELLD02   51.12038   5.02155
# 4  BETR801   51.32766   4.36226

# %%
# Left join
air_quality_join = pd.merge(air_quality, air_stations, how="left", on="location")
air_quality_join
# Out:
#            city country                   date.utc            location  \
# 0     Antwerpen      BE  2019-06-18 06:00:00+00:00             BETR801
# 1     Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 2     Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3     Antwerpen      BE  2019-06-17 06:00:00+00:00             BETR801
# 4     Antwerpen      BE  2019-06-17 05:00:00+00:00             BETR801
# ...         ...     ...                        ...                 ...
# 3173     London      GB  2019-05-07 06:00:00+00:00  London Westminster
# 3174     London      GB  2019-05-07 04:00:00+00:00  London Westminster
# 3175     London      GB  2019-05-07 03:00:00+00:00  London Westminster
# 3176     London      GB  2019-05-07 02:00:00+00:00  London Westminster
# 3177     London      GB  2019-05-07 01:00:00+00:00  London Westminster
#
#      parameter  value   unit  longitude  latitude
# 0         pm25   18.0  µg/m³   51.32766   4.36226
# ...

# %% [markdown]
# There are a lot with out coordinates because we only have five stations

# %%
air_quality_join[~np.isnan(air_quality_join["longitude"]) & ~np.isnan(air_quality_join["latitude"])]
# Out:
#            city country                   date.utc location parameter  value  \
# 0     Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1     Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2     Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3     Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4     Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
# ...         ...     ...                        ...      ...       ...    ...
# 2204  Antwerpen      BE  2019-05-09 01:00:00+00:00  BETR801       no2   20.0
# 2205  Antwerpen      BE  2019-05-08 02:00:00+00:00  BETR801       no2   20.5
# 2206  Antwerpen      BE  2019-05-08 01:00:00+00:00  BETR801       no2   23.0
# 2207  Antwerpen      BE  2019-05-07 02:00:00+00:00  BETR801       no2   45.0
# 2208  Antwerpen      BE  2019-05-07 01:00:00+00:00  BETR801       no2   50.5
#
#        unit  longitude  latitude
# ...

# %%
# Changing table order
air_station_join = pd.merge(air_stations, air_quality, how="left", on="location")
air_station_join
# Out:
#      location  longitude  latitude       city country  \
# 0     FR04014   51.23619   4.38522      Paris      FR
# 1     FR04014   51.23619   4.38522      Paris      FR
# 2     FR04014   51.23619   4.38522      Paris      FR
# 3     FR04014   51.23619   4.38522      Paris      FR
# 4     FR04014   51.23619   4.38522      Paris      FR
# ...       ...        ...       ...        ...     ...
# 1198  BETR801   51.32766   4.36226  Antwerpen      BE
# 1199  BETR801   51.32766   4.36226  Antwerpen      BE
# 1200  BETR801   51.32766   4.36226  Antwerpen      BE
# 1201  BETR801   51.32766   4.36226  Antwerpen      BE
# 1202  BETR801   51.32766   4.36226  Antwerpen      BE
#
#                        date.utc parameter  value   unit
# 0     2019-06-21 00:00:00+00:00       no2   20.0  µg/m³
# 1     2019-06-20 23:00:00+00:00       no2   21.8  µg/m³
# 2     2019-06-20 22:00:00+00:00       no2   26.5  µg/m³
# 3     2019-06-20 21:00:00+00:00       no2   24.9  µg/m³
# ...

# %%
air_station_join[np.isnan(air_station_join["value"])]
# Out:
#      location  longitude  latitude city country date.utc parameter  value unit
# 1004  BELHB23   51.17030   4.34100  NaN     NaN      NaN       NaN    NaN  NaN
# 1005  BELLD01   51.10998   5.00486  NaN     NaN      NaN       NaN    NaN  NaN
# 1006  BELLD02   51.12038   5.02155  NaN     NaN      NaN       NaN    NaN  NaN

# %% [markdown]
# We can specify join key ```air_quality = pd.merge(air_quality, air_quality_parameters, how='left', left_on='parameter', right_on='id')```
